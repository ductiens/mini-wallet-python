# %% [markdown]
# # Fintech Fraud Detection - Exploratory Data Analysis (EDA)
#
# This notebook contains Exploratory Data Analysis for the PaySim transaction dataset to understand fraud distribution, patterns, and engineered features.

# %%
import pandas as pd
import numpy as np

# Load sample data
df = pd.read_csv('../data/sample/paysim_sample.csv')
df.head()
